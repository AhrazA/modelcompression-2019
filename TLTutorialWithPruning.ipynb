Acc: 0.9346
#
# Epoch 15/24
# ----------
# train Loss: 0.4242 Acc: 0.8115
# val Loss: 0.1946 Acc: 0.9346
#
# Epoch 16/24
# ----------
# train Loss: 0.2809 Acc: 0.8893
# val Loss: 0.1766 Acc: 0.9477
#
# Epoch 17/24
# ----------
# train Loss: 0.3033 Acc: 0.8770
# val Loss: 0.1937 Acc: 0.9477
#
# Epoch 18/24
# ----------
# train Loss: 0.3613 Acc: 0.8238
# val Loss: 0.1925 Acc: 0.9412
#
# Epoch 19/24
# ----------
# train Loss: 0.4091 Acc: 0.8238
# val Loss: 0.1812 Acc: 0.9281
#
# Epoch 20/24
# ----------
# train Loss: 0.3797 Acc: 0.8115
# val Loss: 0.2292 Acc: 0.9150
#
# Epoch 21/24
# ----------
# train Loss: 0.3345 Acc: 0.8566
# val Loss: 0.1887 Acc: 0.9477
#
# Epoch 22/24
# ----------
# train Loss: 0.2996 Acc: 0.8893
# val Loss: 0.2131 Acc: 0.9281
#
# Epoch 23/24
# ----------
# train Loss: 0.2858 Acc: 0.8566
# val Loss: 0.2035 Acc: 0.9412
#
# Epoch 24/24
# ----------
# train Loss: 0.3000 Acc: 0.8689
# val Loss: 0.1758 Acc: 0.9477
#
# Training complete in 0m 38s
# Best val Acc: 0.947712

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()

# %%
torch.save(model_conv.state_dict(),f"models/resnetbees18.pt")

# %%
pre_prune_accuracy = copy.copy(best_acc)

# %%
accuracy_thershold = 1./100
prune_perc = 0.
curr_accuracy = copy.copy(pre_prune_accuracy)

# %%
from cifar_classifier import MaskedCifar
from classifier import Classifier
from mnist_classifier import MaskedMNist
from pruning.methods import weight_prune, prune_rate
from pruning.utils import to_var
from resnet import MaskedResNet18, MaskedResNet34, MaskedResNet50, MaskedResNet101, MaskedResNet152
import torch.nn.functional as F

# %%
model = MaskedResNet18(num_classes=2)
model.load_state_dict(torch.load('./models/resnetbees18.pt'))
model.to(device)
# new_model = MaskedResNet18(model)
# Out:
# MaskedResNet18(
#   (conv1): MaskedConv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): MaskedSequential(
#     (0): MaskedBasicBlock(
#       (conv1): MaskedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): MaskedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MaskedBasicBlock(
#       (conv1): MaskedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): MaskedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): MaskedSequential(
#     (0): MaskedBasicBlock(
#       (conv1): MaskedConv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): MaskedConv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): MaskedSequential(
#         (0): MaskedConv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): MaskedBasicBlock(
#       (conv1): MaskedConv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): MaskedConv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): MaskedSequential(
#     (0): MaskedBasicBlock(
#       (conv1): MaskedConv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): MaskedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): MaskedSequential(
#         (0): MaskedConv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): MaskedBasicBlock(
#       (conv1): MaskedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): MaskedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): MaskedSequential(
#     (0): MaskedBasicBlock(
#       (conv1): MaskedConv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): MaskedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): MaskedSequential(
#         (0): MaskedConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): MaskedBasicBlock(
#       (conv1): MaskedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): MaskedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): MaskedLinear(in_features=512, out_features=2, bias=True)
# )

# %%
while (pre_prune_accuracy - curr_accuracy) < accuracy_thershold:
    prune_perc += 5.
    masks = weight_prune(model, prune_perc)
    model.set_mask(masks)
    print(f"Testing at prune percentage {prune_perc}..")
    model, curr_accuracy = train_model(model, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=5)
    print(f"Accuracy achieved: {curr_accuracy}")
    print(f"Change in accuracy: {pre_prune_accuracy - curr_accuracy}")
    print(f"tracking prepruned accuracy: {pre_prune_accuracy}")
# Out:
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 5.0..
# Epoch 0/4
# ----------
# train Loss: 0.4206 Acc: 0.7910
# val Loss: 0.2093 Acc: 0.9412
#
# Epoch 1/4
# ----------
# train Loss: 0.3861 Acc: 0.8443
# val Loss: 0.2179 Acc: 0.9150
#
# Epoch 2/4
# ----------
# train Loss: 0.4074 Acc: 0.8074
# val Loss: 0.2014 Acc: 0.9542
#
# Epoch 3/4
# ----------
# train Loss: 0.3446 Acc: 0.8443
# val Loss: 0.1969 Acc: 0.9477
#
# Epoch 4/4
# ----------
# train Loss: 0.3423 Acc: 0.8320
# val Loss: 0.1857 Acc: 0.9477
#
# Training complete in 0m 11s
# Best val Acc: 0.954248
# Accuracy achieved: 0.954248366013072
# Change in accuracy: -0.006535947712418277
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 10.0..
# Epoch 0/4
# ----------
# train Loss: 0.4331 Acc: 0.8033
# val Loss: 0.1931 Acc: 0.9477
#
# Epoch 1/4
# ----------
# train Loss: 0.4017 Acc: 0.8156
# val Loss: 0.1895 Acc: 0.9477
#
# Epoch 2/4
# ----------
# train Loss: 0.3681 Acc: 0.8443
# val Loss: 0.1906 Acc: 0.9477
#
# Epoch 3/4
# ----------
# train Loss: 0.4102 Acc: 0.8074
# val Loss: 0.2078 Acc: 0.9477
#
# Epoch 4/4
# ----------
# train Loss: 0.3629 Acc: 0.8238
# val Loss: 0.1997 Acc: 0.9346
#
# Training complete in 0m 11s
# Best val Acc: 0.947712
# Accuracy achieved: 0.9477124183006537
# Change in accuracy: 0.0
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 15.0..
# Epoch 0/4
# ----------
# train Loss: 0.3612 Acc: 0.8402
# val Loss: 0.1946 Acc: 0.9477
#
# Epoch 1/4
# ----------
# train Loss: 0.4091 Acc: 0.7869
# val Loss: 0.1918 Acc: 0.9477
#
# Epoch 2/4
# ----------
# train Loss: 0.4006 Acc: 0.8074
# val Loss: 0.2008 Acc: 0.9412
#
# Epoch 3/4
# ----------
# train Loss: 0.4208 Acc: 0.7992
# val Loss: 0.2000 Acc: 0.9412
#
# Epoch 4/4
# ----------
# train Loss: 0.3937 Acc: 0.8279
# val Loss: 0.2177 Acc: 0.9412
#
# Training complete in 0m 11s
# Best val Acc: 0.947712
# Accuracy achieved: 0.9477124183006537
# Change in accuracy: 0.0
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 20.0..
# Epoch 0/4
# ----------
# train Loss: 0.4063 Acc: 0.8033
# val Loss: 0.1930 Acc: 0.9477
#
# Epoch 1/4
# ----------
# train Loss: 0.4072 Acc: 0.8156
# val Loss: 0.2111 Acc: 0.9346
#
# Epoch 2/4
# ----------
# train Loss: 0.3395 Acc: 0.8525
# val Loss: 0.2148 Acc: 0.9346
#
# Epoch 3/4
# ----------
# train Loss: 0.3666 Acc: 0.8279
# val Loss: 0.2271 Acc: 0.9346
#
# Epoch 4/4
# ----------
# train Loss: 0.4037 Acc: 0.8156
# val Loss: 0.2100 Acc: 0.9412
#
# Training complete in 0m 11s
# Best val Acc: 0.947712
# Accuracy achieved: 0.9477124183006537
# Change in accuracy: 0.0
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 25.0..
# Epoch 0/4
# ----------
# train Loss: 0.3779 Acc: 0.8279
# val Loss: 0.1955 Acc: 0.9412
#
# Epoch 1/4
# ----------
# train Loss: 0.3926 Acc: 0.8033
# val Loss: 0.2211 Acc: 0.9412
#
# Epoch 2/4
# ----------
# train Loss: 0.4146 Acc: 0.8074
# val Loss: 0.2090 Acc: 0.9477
#
# Epoch 3/4
# ----------
# train Loss: 0.3764 Acc: 0.8320
# val Loss: 0.2332 Acc: 0.9281
#
# Epoch 4/4
# ----------
# train Loss: 0.3683 Acc: 0.8320
# val Loss: 0.1950 Acc: 0.9477
#
# Training complete in 0m 11s
# Best val Acc: 0.947712
# Accuracy achieved: 0.9477124183006537
# Change in accuracy: 0.0
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 30.0..
# Epoch 0/4
# ----------
# train Loss: 0.3915 Acc: 0.8443
# val Loss: 0.1909 Acc: 0.9412
#
# Epoch 1/4
# ----------
# train Loss: 0.3623 Acc: 0.8361
# val Loss: 0.2018 Acc: 0.9412
#
# Epoch 2/4
# ----------
# train Loss: 0.3890 Acc: 0.8320
# val Loss: 0.2199 Acc: 0.9346
#
# Epoch 3/4
# ----------
# train Loss: 0.3397 Acc: 0.8443
# val Loss: 0.1910 Acc: 0.9477
#
# Epoch 4/4
# ----------
# train Loss: 0.3969 Acc: 0.8197
# val Loss: 0.1990 Acc: 0.9477
#
# Training complete in 0m 11s
# Best val Acc: 0.947712
# Accuracy achieved: 0.9477124183006537
# Change in accuracy: 0.0
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 35.0..
# Epoch 0/4
# ----------
# train Loss: 0.3407 Acc: 0.8648
# val Loss: 0.2373 Acc: 0.9281
#
# Epoch 1/4
# ----------
# train Loss: 0.4119 Acc: 0.8074
# val Loss: 0.1891 Acc: 0.9542
#
# Epoch 2/4
# ----------
# train Loss: 0.3802 Acc: 0.8238
# val Loss: 0.2105 Acc: 0.9477
#
# Epoch 3/4
# ----------
# train Loss: 0.4318 Acc: 0.7910
# val Loss: 0.1983 Acc: 0.9542
#
# Epoch 4/4
# ----------
# train Loss: 0.4404 Acc: 0.8074
# val Loss: 0.2082 Acc: 0.9477
#
# Training complete in 0m 11s
# Best val Acc: 0.954248
# Accuracy achieved: 0.954248366013072
# Change in accuracy: -0.006535947712418277
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 40.0..
# Epoch 0/4
# ----------
# train Loss: 0.3911 Acc: 0.8033
# val Loss: 0.2203 Acc: 0.9346
#
# Epoch 1/4
# ----------
# train Loss: 0.3651 Acc: 0.8074
# val Loss: 0.2294 Acc: 0.9477
#
# Epoch 2/4
# ----------
# train Loss: 0.3555 Acc: 0.8484
# val Loss: 0.2127 Acc: 0.9477
#
# Epoch 3/4
# ----------
# train Loss: 0.4168 Acc: 0.7992
# val Loss: 0.2038 Acc: 0.9477
#
# Epoch 4/4
# ----------
# train Loss: 0.4373 Acc: 0.8033
# val Loss: 0.1964 Acc: 0.9542
#
# Training complete in 0m 11s
# Best val Acc: 0.954248
# Accuracy achieved: 0.954248366013072
# Change in accuracy: -0.006535947712418277
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 45.0..
# Epoch 0/4
# ----------
# train Loss: 0.3867 Acc: 0.8156
# val Loss: 0.2065 Acc: 0.9412
#
# Epoch 1/4
# ----------
# train Loss: 0.4304 Acc: 0.7951
# val Loss: 0.2029 Acc: 0.9346
#
# Epoch 2/4
# ----------
# train Loss: 0.3934 Acc: 0.8361
# val Loss: 0.1977 Acc: 0.9477
#
# Epoch 3/4
# ----------
# train Loss: 0.3962 Acc: 0.8279
# val Loss: 0.1975 Acc: 0.9542
#
# Epoch 4/4
# ----------
# train Loss: 0.4531 Acc: 0.7787
# val Loss: 0.1962 Acc: 0.9477
#
# Training complete in 0m 10s
# Best val Acc: 0.954248
# Accuracy achieved: 0.954248366013072
# Change in accuracy: -0.006535947712418277
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 50.0..
# Epoch 0/4
# ----------
# train Loss: 0.4062 Acc: 0.8197
# val Loss: 0.1983 Acc: 0.9412
#
# Epoch 1/4
# ----------
# train Loss: 0.4494 Acc: 0.7869
# val Loss: 0.2025 Acc: 0.9412
#
# Epoch 2/4
# ----------
# train Loss: 0.3490 Acc: 0.8607
# val Loss: 0.2094 Acc: 0.9346
#
# Epoch 3/4
# ----------
# train Loss: 0.4089 Acc: 0.8074
# val Loss: 0.2105 Acc: 0.9346
#
# Epoch 4/4
# ----------
# train Loss: 0.3580 Acc: 0.8279
# val Loss: 0.2104 Acc: 0.9412
#
# Training complete in 0m 11s
# Best val Acc: 0.941176
# Accuracy achieved: 0.9411764705882353
# Change in accuracy: 0.0065359477124183885
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 55.0..
# Epoch 0/4
# ----------
# train Loss: 0.4357 Acc: 0.8197
# val Loss: 0.2274 Acc: 0.9346
#
# Epoch 1/4
# ----------
# train Loss: 0.3835 Acc: 0.8402
# val Loss: 0.2289 Acc: 0.9412
#
# Epoch 2/4
# ----------
# train Loss: 0.4028 Acc: 0.8238
# val Loss: 0.2272 Acc: 0.9412
#
# Epoch 3/4
# ----------
# train Loss: 0.3983 Acc: 0.8115
# val Loss: 0.2231 Acc: 0.9281
#
# Epoch 4/4
# ----------
# train Loss: 0.3949 Acc: 0.7910
# val Loss: 0.2326 Acc: 0.9346
#
# Training complete in 0m 10s
# Best val Acc: 0.941176
# Accuracy achieved: 0.9411764705882353
# Change in accuracy: 0.0065359477124183885
# tracking prepruned accuracy: 0.9477124183006537
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  ReLU(inplace)
# Skipping masking of layer:  BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Skipping masking of layer:  AdaptiveAvgPool2d(output_size=(1, 1))
# Testing at prune percentage 60.0..
# Epoch 0/4
# ----------
# train Loss: 0.3723 Acc: 0.8279
# val Loss: 0.2266 Acc: 0.9281
#
# Epoch 1/4
# ----------
# train Loss: 0.4523 Acc: 0.7910
# val Loss: 0.2338 Acc: 0.9281
#
# Epoch 2/4
# ----------
# train Loss: 0.3646 Acc: 0.8525
# val Loss: 0.2349 Acc: 0.9281
#
# Epoch 3/4
# ----------
# train Loss: 0.4179 Acc: 0.8197
# val Loss: 0.2328 Acc: 0.9216
#
# Epoch 4/4
# ----------
# train Loss: 0.3894 Acc: 0.8648
# val Loss: 0.2341 Acc: 0.9346
#
# Training complete in 0m 11s
# Best val Acc: 0.934641
# Accuracy achieved: 0.934640522875817
# Change in accuracy: 0.013071895424836666
# tracking prepruned accuracy: 0.9477124183006537
